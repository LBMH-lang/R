# %% [markdown]
# <a href="https://colab.research.google.com/github/LBMH-lang/R/blob/main/BT01_Th%C3%A1p_H%C3%A0_N%E1%BB%99i.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#BT01: Tháp Hà Nội
def thapHaNoi(n, toaMot, toaHai, toaBa):

if n == 1:
	print "chuyen tu", toaMot, "sang", toaBa

else:
	thapHaNoi(n-1, toaMot, toaBa, toaHai)
	print "chuyen tu", toaMot, "sang", toaBa
	thapHaNoi(n-1, toaHai, toaMot, toaBa)
